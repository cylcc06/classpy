# %% [markdown]
# ## 对应分析

# %% [markdown]
# |变量|说明|标签|
# |:--:|:--:|:--|
# |NO|编号|-|
# |salary|收入|1:[0 1000], 2:[1000 3000], 3:[3001 5000], 4:[5001 7000], 5:[7001 9000], 6:>9000|
# |educ|教育程度|1:高中以下, 2:大专, 3:本科, 4:大于硕士|
# |freq|频次|1:1次, 2:2-3次, 3:4-5次, 4:6-8次, 5:9-12次, 6:>13次|
# |compan|购物原因|1:家人,2:情人, 3:朋友, 4: 同学, 5:客户, 6:无聊|
# |purpose|目的|1:享受, 2:陪同异性, 3:生活用品, 4:公事, 5:无聊|
# |average|单次平均消费|1:小于50, 2:[50 99], 3: [100,149], 4:[150 199], 5:≥200|

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv(r'购物信息.csv')
df.head()
# Out:
#    NO  salary  educ  freq  compan  purpose  average
# 0   1       3     4     4       3        2        2
# 1   2       4     4     1       1        1        2
# 2   3       3     3     6       2        1        2
# 3   4       4     4     2       3        2        4
# 4   5       1     3     1       3        2        2

# %%
purpose_dict = {1:'enjoyment', 2:'opposite sex', 3:'daily use', 
                4:'business', 5:'no reason'}
average_dict = {1:'<50', 2:'[50 99]', 3:'[100 149]', 4:'[150 199]', 
                5:'>200'}
df.purpose.replace(purpose_dict, inplace=True)
df.average.replace(average_dict, inplace=True)

cross_table = pd.crosstab(df.purpose, df.average)
cross_table
# Out:
# average       <50  >200  [100 149]  [150 199]  [50 99]
# purpose
# business        1     4          9          4        4
# daily use       1     2         10          3        9
# enjoyment       0     6         15          7       48
# no reason       3     1          1          0        5
# opposite sex    8     6         15         12       48

# %%
import numpy as np
from numpy.linalg import svd

class CA(object):
    """Simple corresondence analysis.
    
    Inputs
    ------
    ct : array_like, shape (n_samples, n_features)
      Two-way contingency table, training set, where `n_samples`
      is the number of samples and `n_features` is the number of features.
          
    Attributes
    ------
    列主成分坐标轴
    F_ : array, shape (n_features, K)
      principal coordinates of columns. Where `K` = min(`n_features`, `n_samples`).
      
    行主成分坐标轴
    G_ : array, shape (n_samples, K)
      principal coordinates of rows. Where `K` = min(`n_features`, `n_samples`).
    
    explained_variance_ratio_ : array, shape(K, )
      Percentage of variance explained by each of the selected components.
    
    Notes
    -----
    The implementation follows that presented in 'Correspondence
    Analysis in R, with Two- and Three-dimensional Graphics: The ca
    Package,' Journal of Statistical Software, May 2007, Volume 20,
    Issue 3.
    """
    
    def __init__(self, cross_table):
        N = np.matrix(cross_table, dtype=float)

        # correspondence matrix from contingency table
        #频次变频率
        P = N / N.sum()

        # row and column marginal totals of P as vectors
        r = P.sum(axis=1)
        c = P.sum(axis=0).T

        # diagonal matrices of row/column sums
        #对角阵
        D_r_rsq = np.diag(1. / np.sqrt(r.A1))
        D_c_rsq = np.diag(1. / np.sqrt(c.A1))

        # the matrix of standarized residuals
        #P - r * c.T (中心化)
        Z = D_r_rsq * (P - r * c.T) * D_c_rsq

        # compute the SVD
        #SVD分解
        U, D_a, V = svd(Z, full_matrices=False)
        D_a = np.asmatrix(np.diag(D_a))
        V = V.T

        # principal coordinates of columns
        #主成分
        F = D_c_rsq * V * D_a

        # principal coordinates of rows
        #行变换
        G = D_r_rsq * U * D_a

        # standard coordinates of rows
        X = D_r_rsq * U

        # standard coordinates of columns
        Y = D_c_rsq * V
        #特征值
        eigenvals = np.diagonal(D_a) ** 2
        #特征值可以解释的特征变异
        explained_variance_ratio = eigenvals.cumsum() / eigenvals.sum()

        # the total variance of the data matrix 
        #总数据变异
        inertia = sum([(P[i,j] - r[i,0] * c[j,0])**2 / (r[i,0] * c[j,0])
                       for i in range(N.shape[0])
                       for j in range(N.shape[1])])  # equals np.power(S, 2).sum() or eigenvalus.sum() or np.trace(S.T * S)

        self.F_ = F.A
        self.G_ = G.A
        self.inertia_ = inertia
        self.eigenvals_ = eigenvals
        self.explained_variance_ratio_ = explained_variance_ratio

# %%
ca = CA(cross_table)

print(ca.explained_variance_ratio_)
# Out:
# [ 0.51057984  0.92001143  0.96850523  1.          1.        ]

# %% [markdown]
# R型和Q型分析的特征向量（加权后）

# %%
F = ca.F_ 
G = ca.G_

print(F[:, :2])
# Out:
# [[ 0.75903754 -0.81340802]
#  [-0.22718477 -0.2089492 ]
#  [-0.38023687 -0.15354446]
#  [-0.19191092 -0.0661804 ]
#  [ 0.16184693  0.21001976]]

# %% [markdown]
# 绘制感知图

# %%
import matplotlib.pyplot as plt

for i, s in enumerate(cross_table.columns):
    x, y = F[i, 0], F[i, 1]
    plt.plot(x, y, 'bo')
    plt.text(x, y, s, va='bottom', ha='left', color='b')
    
for i, s in enumerate(cross_table.index):
    x, y = G[i, 0], G[i, 1]
    plt.plot(x, y, 'r^')
    plt.text(x, y, s, va='bottom', ha='left', color='r')

# %% [markdown]
# ## 多维尺度分析
# - 使用美国各大城市距离数据CITY_DISTANCE

# %%
df = pd.read_csv('CITY_DISTANCE.csv', skipinitialspace=True)
df
# Out:
#            City  Atlanta  Chicago  Denver  Houston  LosAngeles   Miami  \
# 0       Atlanta        0      NaN     NaN      NaN         NaN     NaN
# 1       Chicago      587      0.0     NaN      NaN         NaN     NaN
# 2        Denver     1212    920.0     0.0      NaN         NaN     NaN
# 3       Houston      701    940.0   879.0      0.0         NaN     NaN
# 4    LosAngeles     1936   1745.0   831.0   1374.0         0.0     NaN
# 5         Miami      604   1188.0  1726.0    968.0      2339.0     0.0
# 6       NewYork      748    713.0  1631.0   1420.0      2451.0  1092.0
# 7  SanFrancisco     2139   1858.0   949.0   1645.0       347.0  2594.0
# 8       Seattle     2182   1737.0  1021.0   1891.0       959.0  2734.0
# 9   Wanshington      543    597.0  1494.0   1220.0      2300.0   923.0
#
#    NewYork  SanFrancisco  Seattle  Wanshington
# 0      NaN           NaN      NaN          NaN
# 1      NaN           NaN      NaN          NaN
# 2      NaN           NaN      NaN          NaN
# 3      NaN           NaN      NaN          NaN
# 4      NaN           NaN      NaN          NaN
# 5      NaN           NaN      NaN          NaN
# 6      0.0           NaN      NaN          NaN
# 7   2571.0           0.0      NaN          NaN
# 8   2408.0         678.0      0.0          NaN
# 9    205.0        2442.0   2329.0          0.0

# %%
# n = len(cd_array)
df_filled = df.fillna(0)
distance_array = np.array(df_filled.iloc[:, 1:])
cities = distance_array + distance_array.T
pd.DataFrame(cities)
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0     0.0   587.0  1212.0   701.0  1936.0   604.0   748.0  2139.0  2182.0
# 1   587.0     0.0   920.0   940.0  1745.0  1188.0   713.0  1858.0  1737.0
# 2  1212.0   920.0     0.0   879.0   831.0  1726.0  1631.0   949.0  1021.0
# 3   701.0   940.0   879.0     0.0  1374.0   968.0  1420.0  1645.0  1891.0
# 4  1936.0  1745.0   831.0  1374.0     0.0  2339.0  2451.0   347.0   959.0
# 5   604.0  1188.0  1726.0   968.0  2339.0     0.0  1092.0  2594.0  2734.0
# 6   748.0   713.0  1631.0  1420.0  2451.0  1092.0     0.0  2571.0  2408.0
# 7  2139.0  1858.0   949.0  1645.0   347.0  2594.0  2571.0     0.0   678.0
# 8  2182.0  1737.0  1021.0  1891.0   959.0  2734.0  2408.0   678.0     0.0
# 9   543.0   597.0  1494.0  1220.0  2300.0   923.0   205.0  2442.0  2329.0
#
#         9
# 0   543.0
# 1   597.0
# 2  1494.0
# 3  1220.0
# 4  2300.0
# 5   923.0
# 6   205.0
# 7  2442.0
# 8  2329.0
# 9     0.0

# %% [markdown]
# 建模

# %%
from sklearn.manifold import MDS

mds = MDS(n_components=2, dissimilarity='precomputed', random_state=123)

# %%
mds.fit(cities)
mds.stress_
# Out:
# 350.0770309073701

# %%
mds.embedding_
# Out:
# array([[  716.61625448,  -148.16931503],
#        [  384.93295013,   338.19627187],
#        [ -481.42120431,    25.85317473],
#        [  157.13523411,  -574.28615625],
#        [-1207.2958236 ,  -371.75217682],
#        [ 1127.90413892,  -587.76572233],
#        [ 1077.08560846,   506.5484897 ],
#        [-1420.83429788,   -95.07851906],
#        [-1336.36870742,   581.2975099 ],
#        [  982.24584712,   325.1564433 ]])

# %% [markdown]
# 绘制感知图

# %%
x = mds.embedding_[:, 0]
y = mds.embedding_[:, 1]
plt.scatter(x, y)
for a, b, s in zip(x, y, df['City']):
    plt.text(a, b, s, fontsize=12)
plt.show()

# %% [markdown]
# 练习：CAR_BRANDS.csv文件保存了五个用户对于十个汽车品牌相似度的评价，请使用MDS方法分析用户对汽车品牌的感知
