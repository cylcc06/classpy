# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os

# os.chdir('Q:/data')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 对通信消费数据profile_telecom进行因子分析

# %%
profile = pd.read_csv("profile_telecom.csv")
profile.head()
# Out:
#         ID  cnt_call  cnt_msg  cnt_wei  cnt_web
# 0  1964627        46       90       36       31
# 1  3107769        53        2        0        2
# 2  3686296        28       24        5        8
# 3  3961002         9        2        0        4
# 4  4174839       145        2        0        1

# %%
data = profile.loc[ :, 'cnt_call':]
data.corr(method='pearson')
# Out:
#           cnt_call   cnt_msg   cnt_wei   cnt_web
# cnt_call  1.000000  0.052096  0.117832  0.114190
# cnt_msg   0.052096  1.000000  0.510686  0.739506
# cnt_wei   0.117832  0.510686  1.000000  0.950492
# cnt_web   0.114190  0.739506  0.950492  1.000000

# %% [markdown]
# 对数据进行标准化

# %% [markdown]
# http://scikit-learn.org/stable/modules/preprocessing.html#preprocessing

# %%
from sklearn.preprocessing import scale

data_scaled = scale(data)

telecom_pca = PCA(n_components=2, whiten=True).fit(data_scaled)
telecom_pca.explained_variance_ratio_
# Out:
# array([ 0.62510442,  0.24620209])

# %%
telecom_pca.components_
# Out:
# array([[ 0.11085805,  0.50974123,  0.57909319,  0.62651852],
#        [ 0.99020127, -0.12736724, -0.01900236, -0.05401806]])

# %%
telecom_pca.transform(data_scaled)
# Out:
# array([[ 2.30183615, -0.89716788],
#        [-0.74694076, -0.04035188],
#        [-0.11502116, -0.59578592],
#        ...,
#        [ 2.19333782,  0.04953167],
#        [-0.07833419, -0.10944885],
#        [-0.6621524 ,  1.16641367]])

# %% [markdown]
# ### 因子分析

# %%
from fa_kit import FactorAnalysis
from fa_kit import plotting as fa_plotting

fa = FactorAnalysis.load_data_samples(
        data_scaled,
        preproc_demean=True,
        preproc_scale=True
        )
fa.extract_components()

# %%
fa.find_comps_to_retain(method='top_n',num_keep=2) # 保留2个因子
fa.rotate_components(method='varimax') # 采用最大方差旋转
# fa_plotting.graph_summary(fa) # 因子载荷绘图

fa_comps = pd.DataFrame(fa.comps["rot"])
fa_comps
# Out:
#           0         1
# 0  0.002284  0.996385
# 1  0.520586 -0.071056
# 2  0.577715  0.044221
# 3  0.628674  0.014582

# %%
fa_scores = fa.get_component_scores(data_scaled)

pd.DataFrame(fa_scores, columns=['phone_call', 'value_added'])
# Out:
#      phone_call  value_added
# 0      3.718276    -0.488759
# 1     -1.170693    -0.168666
# 2     -0.116459    -0.608050
# 3     -1.053884    -0.829247
# 4     -1.226677     1.216917
# 5     -1.102273     1.833129
# 6      1.228434    -0.496427
# 7     -1.143891    -0.051681
# 8     -0.229023     0.332303
# 9     -1.168964     0.585114
# 10    -1.230929    -0.637382
# 11    -1.229684    -0.094660
# 12     1.804454    -0.117066
# 13    -1.168861     0.630341
# 14    -1.091083    -0.164452
# 15     0.305132    -0.503642
# 16     2.046610     0.579790
# 17     2.009721     0.283038
# 18    -0.963088    -0.795249
# 19     1.035924    -0.629192
# 20    -1.290750    -0.925190
# 21     0.220560     0.315209
# 22    -1.229719    -0.109736
# 23     1.993687     0.158046
# 24    -0.421223    -0.762011
# 25     3.823592     1.299611
# 26    -0.987159     0.278740
# 27    -0.398600     0.190594
# 28    -1.167547     1.203214
# 29    -0.936598    -0.813945
# ..          ...          ...
# 570   -0.910831     0.258207
# 571   -0.576469    -0.599285
# 572    1.788488    -0.367010
# 573    0.819506     0.208328
# 574    2.029873    -0.336002
# 575   -1.086455    -0.804089
# 576   -0.768362    -0.782885
# 577   -1.287777     0.371311
# 578   -1.154067     7.082699
# 579    0.384190     0.511694
# 580    4.811985     1.992490
# 581   -0.634007     1.360229
# 582   -0.415003     0.389058
# 583   -0.261348    -0.622250
# 584   -1.065319    -0.499735
# 585   -1.290439    -0.789510
# 586   -1.171280    -0.424951
# 587   -0.675217    -0.665870
# 588   -1.184512    -0.879370
# 589   -1.290404    -0.774434
# 590   -0.006288    -0.418139
# 591   -0.934766    -0.014938
# 592   -0.768432    -0.813036
# 593   -1.072193    -0.684908
# 594    7.775925    -0.090418
# 595    0.146777    -0.445388
# 596   -0.176349    -0.926010
# 597    3.445119     0.427193
# 598   -0.111386    -0.121568
# 599   -1.167927     1.037382
#
# [600 rows x 2 columns]
